# %%
import csv
import pandas as pd
import chardet
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Concatenating all the monthly data into one data frame.

# %%
#Read in 2018 data
january2018_df = pd.read_csv('CrimeDataByMonth/January2018.csv')
february2018_df = pd.read_csv('CrimeDataByMonth/February2018.csv')
march2018_df = pd.read_csv('CrimeDataByMonth/March2018.csv')
april2018_df = pd.read_csv('CrimeDataByMonth/April2018.csv')
may2018_df = pd.read_csv('CrimeDataByMonth/May2018.csv')
june2018_df = pd.read_csv('CrimeDataByMonth/June2018.csv')

#Create 2018 pd and then csv
frames_2018 = [january2018_df, 
               february2018_df, 
               march2018_df,
               april2018_df, 
               may2018_df, 
               june2018_df ]

crimes_2018_df = pd.concat(frames_2018, sort = False)
crimes_2018_df.columns
crimes_2018_df.head()
# Out:
#    Complaint CodedMonth         DateOccur FlagCrime FlagUnfounded  \
# 0  18-001804    2018-01  01/01/2018 00:01         Y
# 1  18-002209    2018-01  01/01/2018 00:01         Y
# 2  18-000063    2018-01  01/01/2018 00:01         Y
# 3  18-000018    2018-01  01/01/2018 00:01         Y
# 4  18-000003    2018-01  01/01/2018 00:01         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1               31111         1
# 1                         1              142320         5
# 2                         1               67601         4
# 3                         1               41011         2
# 4                         1               41011         3
#
#                                     Description ILEADSAddress   ILEADSStreet  \
# 0     ROBBERY-HIGHWAY  /FIREARM USED/SUCCESSFUL          6431      IDAHO AVE
# 1   DESTRUCTION OF PROPERTY-MALICIOUS/PRIV PROP          5506      ETZEL AVE
# ...

# %%
#Read in 2017 data
january2017_df = pd.read_csv('CrimeDataByMonth/January2017.csv')
february2017_df = pd.read_csv('CrimeDataByMonth/February2017.csv')
march2017_df = pd.read_csv('CrimeDataByMonth/March2017.csv')
april2017_df = pd.read_csv('CrimeDataByMonth/April2017.csv')
may2017_df = pd.read_csv('CrimeDataByMonth/May2017.csv')
june2017_df = pd.read_csv('CrimeDataByMonth/June2017.csv')
july2017_df = pd.read_csv('CrimeDataByMonth/July2017.csv')
august2017_df = pd.read_csv('CrimeDataByMonth/August2017.csv')
september2017_df = pd.read_csv('CrimeDataByMonth/September2017.csv')
october2017_df = pd.read_csv('CrimeDataByMonth/October2017.csv')
november2017_df = pd.read_csv('CrimeDataByMonth/November2017.csv')
december2017_df = pd.read_csv('CrimeDataByMonth/December2017.csv')

#Create 2017 pd and then csv
frames_2017 = [january2017_df, 
               february2017_df, 
               march2017_df,
               april2017_df, 
               may2017_df, 
               june2017_df,
               july2017_df,
               august2017_df,
               september2017_df,
               october2017_df,
               november2017_df,
               december2017_df]

crimes_2017_df = pd.concat(frames_2017, sort = False) 
crimes_2017_df.columns
#Some of the cvs files have more data columns that are not needed for our analyisis. We will use only those in the 2018 file.
crimes_2017_df=crimes_2017_df[crimes_2018_df.columns] 
crimes_2017_df.head()
# Out:
#    Complaint CodedMonth         DateOccur FlagCrime FlagUnfounded  \
# 0  17-005061    2017-01  01/01/2004 00:01         Y
# 1  17-000381    2017-01  01/01/2013 12:00         Y
# 2  17-001900    2017-01  01/01/2013 12:00         Y
# 3  17-000294    2017-01  01/01/2016 17:00         Y
# 4  17-002617    2017-01  01/01/2016 22:00         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1               21000         5
# 1                         1              115400         6
# 2                         1              179210         5
# 3                         1              142320         5
# 4                         1              171200         6
#
#                                    Description ILEADSAddress  \
# 0                             RAPE -- FORCIBLE          5200
# 1         STLG BY DECEIT/IDENTITY THEFT REPORT          8005
# 2     SEX OFFNS-CHILD MOLESTATION-FIRST DEGREE          5200
# ...

# %%
#Read in 2016 data
january2016_df = pd.read_csv('CrimeDataByMonth/January2016.csv')
february2016_df = pd.read_csv('CrimeDataByMonth/February2016.csv')
march2016_df = pd.read_csv('CrimeDataByMonth/March2016.csv')
april2016_df = pd.read_csv('CrimeDataByMonth/April2016.csv')
may2016_df = pd.read_csv('CrimeDataByMonth/May2016.csv')
june2016_df = pd.read_csv('CrimeDataByMonth/June2016.csv')
july2016_df = pd.read_csv('CrimeDataByMonth/July2016.csv')
august2016_df = pd.read_csv('CrimeDataByMonth/August2016.csv')
september2016_df = pd.read_csv('CrimeDataByMonth/September2016.csv')
october2016_df = pd.read_csv('CrimeDataByMonth/October2016.csv')
november2016_df = pd.read_csv('CrimeDataByMonth/November2016.csv')
december2016_df = pd.read_csv('CrimeDataByMonth/December2016.csv')

#Create 2016 pd and then csv
frames_2016 = [january2016_df, 
               february2016_df, 
               march2016_df,
               april2016_df, 
               may2016_df, 
               june2016_df,
               july2016_df,
               august2016_df,
               september2016_df,
               october2016_df,
               november2016_df,
               december2016_df]

crimes_2016_df = pd.concat(frames_2016, sort = False)
crimes_2016_df.columns
crimes_2016_df=crimes_2016_df[crimes_2018_df.columns] 
crimes_2016_df.head()
# Out:
#    Complaint CodedMonth         DateOccur FlagCrime FlagUnfounded  \
# 0  16-001715    2016-01  01/01/2011 00:01         Y
# 1  16-003615    2016-01  01/01/2015 00:00         Y
# 2  16-000219    2016-01  01/01/2015 01:30         Y
# 3  16-003339    2016-01  01/01/2015 12:00         Y
# 4  16-000189    2016-01  01/01/2015 20:30         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1               21000         1
# 1                         1              115400         0
# 2                         1               64601         3
# 3                         1              115400         6
# 4                         1              142320         5
#
#                                    Description ILEADSAddress  ILEADSStreet  \
# 0                             RAPE -- FORCIBLE          3700    WYOMING ST
# 1         STLG BY DECEIT/IDENTITY THEFT REPORT             0       UNKNOWN
# ...

# %%
#Read in 2015 data
january2015_df = pd.read_csv('CrimeDataByMonth/January2015.csv')
february2015_df = pd.read_csv('CrimeDataByMonth/February2015.csv')
march2015_df = pd.read_csv('CrimeDataByMonth/March2015.csv')
april2015_df = pd.read_csv('CrimeDataByMonth/April2015.csv')
may2015_df = pd.read_csv('CrimeDataByMonth/May2015.csv')
june2015_df = pd.read_csv('CrimeDataByMonth/June2015.csv')
july2015_df = pd.read_csv('CrimeDataByMonth/July2015.csv')
august2015_df = pd.read_csv('CrimeDataByMonth/August2015.csv')
september2015_df = pd.read_csv('CrimeDataByMonth/September2015.csv')
october2015_df = pd.read_csv('CrimeDataByMonth/October2015.csv')
november2015_df = pd.read_csv('CrimeDataByMonth/November2015.csv')
december2015_df = pd.read_csv('CrimeDataByMonth/December2015.csv')

#Create 2015 pd and then csv
frames_2015 = [january2015_df, 
               february2015_df, 
               march2015_df,
               april2015_df, 
               may2015_df, 
               june2015_df,
               july2015_df,
               august2015_df,
               september2015_df,
               october2015_df,
               november2015_df,
               december2015_df]

crimes_2015_df = pd.concat(frames_2015, sort = False)
crimes_2015_df.columns
crimes_2015_df=crimes_2015_df[crimes_2018_df.columns] 
crimes_2015_df.head()
# Out:
#    Complaint CodedMonth       DateOccur FlagCrime FlagUnfounded  \
# 0  15-003833    2015-01   1/1/2001 0:01         Y
# 1  15-002297    2015-01   1/1/2009 0:09         Y
# 2  15-003984    2015-01   1/1/2013 0:01         Y
# 3  15-002377    2015-01  1/1/2014 12:00         Y
# 4  15-000021    2015-01   1/1/2015 0:01         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1               21000         5
# 1                         1               21000         5
# 2                         1              179210         5
# 3                         1              115400         6
# 4                         1              142320         6
#
#                                    Description ILEADSAddress  \
# 0                             RAPE -- FORCIBLE          3000
# 1                             RAPE -- FORCIBLE          5100
# 2     SEX OFFNS-CHILD MOLESTATION-FIRST DEGREE          2800
# ...

# %%
#Read in 2014 data
january2014_df = pd.read_csv('CrimeDataByMonth/January2014.csv')
february2014_df = pd.read_csv('CrimeDataByMonth/February2014.csv')
march2014_df = pd.read_csv('CrimeDataByMonth/March2014.csv')
april2014_df = pd.read_csv('CrimeDataByMonth/April2014.csv')
may2014_df = pd.read_csv('CrimeDataByMonth/May2014.csv')
june2014_df = pd.read_csv('CrimeDataByMonth/June2014.csv')
july2014_df = pd.read_csv('CrimeDataByMonth/July2014.csv')
august2014_df = pd.read_csv('CrimeDataByMonth/August2014.csv')
september2014_df = pd.read_csv('CrimeDataByMonth/September2014.csv')
october2014_df = pd.read_csv('CrimeDataByMonth/October2014.csv')
november2014_df = pd.read_csv('CrimeDataByMonth/November2014.csv')
december2014_df = pd.read_csv('CrimeDataByMonth/December2014.csv')

#Create 2014 pd and then csv
frames_2014 = [january2014_df, 
               february2014_df, 
               march2014_df,
               april2014_df, 
               may2014_df, 
               june2014_df,
               july2014_df,
               august2014_df,
               september2014_df,
               october2014_df,
               november2014_df,
               december2014_df]

crimes_2014_df = pd.concat(frames_2014, sort = False)
crimes_2014_df.columns
crimes_2014_df=crimes_2014_df[crimes_2018_df.columns] 
crimes_2014_df.head()
# Out:
#    Complaint CodedMonth         DateOccur FlagCrime FlagUnfounded  \
# 0  14-003128    2014-01  01/01/2008 08:00         Y
# 1  14-000962    2014-01  01/01/2012 00:01         Y
# 2  14-001677    2014-01  01/01/2012 16:33         Y
# 3  14-001027    2014-01  01/01/2013 10:00         Y
# 4  14-000052    2014-01  01/01/2014 00:01         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1              179210         1
# 1                         1               21000         1
# 2                         1               21000         1
# 3                         1               51312         3
# 4                         1               41011         5
#
#                                     Description ILEADSAddress  ILEADSStreet  \
# 0      SEX OFFNS-CHILD MOLESTATION-FIRST DEGREE         04465      DELOR ST
# 1                              RAPE -- FORCIBLE         04249  MICHIGAN AVE
# ...

# %%
frames_all = [crimes_2014_df,
              crimes_2015_df,
              crimes_2016_df,
              crimes_2017_df,
              crimes_2018_df]

crimes_total_df = pd.concat(frames_all, sort=False)

crimes_total_df.to_csv("stl_crime_data_2014_to_June_2018")
crimes_total_df.head()
# Out:
#    Complaint CodedMonth         DateOccur FlagCrime FlagUnfounded  \
# 0  14-003128    2014-01  01/01/2008 08:00         Y
# 1  14-000962    2014-01  01/01/2012 00:01         Y
# 2  14-001677    2014-01  01/01/2012 16:33         Y
# 3  14-001027    2014-01  01/01/2013 10:00         Y
# 4  14-000052    2014-01  01/01/2014 00:01         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  \
# 0                         1              179210         1
# 1                         1               21000         1
# 2                         1               21000         1
# 3                         1               51312         3
# 4                         1               41011         5
#
#                                     Description ILEADSAddress  ILEADSStreet  \
# 0      SEX OFFNS-CHILD MOLESTATION-FIRST DEGREE         04465      DELOR ST
# 1                              RAPE -- FORCIBLE         04249  MICHIGAN AVE
# ...

# %% [markdown]
# ## Get the Crime category as a column. The first two numbers in the six digit crime code give the category. If there are only five number it is because the leading zero is cut off.
#
# * 01 – Homicide (Keep in mind that Excel will, by default, cut off the leading zero, so the number will look like 10000).
# * 02 – Rape (i.e. 20000 – 29999)
# * 03 – Robbery (i.e. 30000 – 39999)
# * 04 – Aggravated Assault
# * 05 – Burglary
# * 06 – Larceny
# * 07 – Vehicle Theft
# * 08 – Arson (08 and 09 are switched on the missouri list, but we will go with the st. louis list)
# * 09 – Other Assults
# * 10 – Forgery and Counterfeiting
# * 11 – Fraud
# * 12 – Embezzlement
# * 13 – Stolen Property
# * 14 – Vandalism
# * 15 – Weapons
# * 16 – Prositituion and Commericialized Vice
# * 17 – Sex Offenses (except rape, prositituion and commercialized vice)
# * 18 – Drug Abuse Violations
# * 19 – Gambling
# * 20 – Offenses Agains the Family and Children
# * 21 – Driving Under the Influence
# * 22 – Liquor Laws
# * 23 – Drunkenness
# * 24 – Disorderly Conduct
# * 25 – Vagrancy
# * 26 – Other Offences
#
# #### We will separate these into
# Violent Crimes (V):
# 01 – 09
#
# Non-violent neighborhood Crimes (N):
# 13 – 18 and 20 – 25
#
# non-violent non-neighborhood Crimes (We will ignore these for our purposes):
# 10 – 12, 19 and 26
#
#
# http://www.slmpd.org/Crime/CrimeDataFrequentlyAskedQuestions.pdf
# https://ucr.mshp.dps.mo.gov/ucr/ucrhome.nsf/5cc4aefff80bfebe86256f3f005fd511/56ec43535549b5e7862573b7006e23b1/$FILE/State%20Agency%20UCR%20User%20Guide.pdf

# %%
crimes_total_df["Crime Category"]=crimes_total_df["Crime"].floordiv(10000)
crimes_total_df["V/N"] =  np.where(crimes_total_df["Crime Category"]<10,"V",
                                   np.where(crimes_total_df["Crime Category"]<12, "X",#OR 
                                            np.where(crimes_total_df["Crime Category"]==19, "X", #OR 
                                                     np.where(crimes_total_df["Crime Category"]>25,"X","N"))))


#drop Neighborhood = 0 which is entries with incomplete addresses

#Used these to check number of crime data with zero neighborhood removed
crimes_total_df.shape
crimes_total_df.loc[crimes_total_df["Neighborhood"] == 0]

crimes_df = crimes_total_df[crimes_total_df.Neighborhood != 0]
crimes_df.shape
# Out:
# (219726, 22)

# %%
#Get count of Violent and Non-Violent crimes by neighborhood.

#look only at rows where the crime is N or V, ignore X

#Used these to check number of crime data with X category removed
crimes_df.shape
crimes_df.loc[crimes_df["V/N"] == "X"].shape

VNcrimes_df = crimes_df[crimes_df["V/N"] != "X"]
VNcrimes_df.shape

#Make dataframe with neighborhoods for rows and 2 columns: V and N

#VNcrimes_df.groupby(["Neighborhood","V/N"])["V/N"].count()

neighborhood_crime_counts_df = pd.DataFrame(pd.pivot_table(VNcrimes_df,values="Crime", index="Neighborhood", columns=["V/N"], aggfunc=len))
neighborhood_crime_counts_df
# Out:
# V/N              N     V
# Neighborhood
# 1             1181  3959
# 2              627  1496
# 3              170   751
# 4              319  1255
# 5              989  3438
# 6              255  1046
# 7              297  1398
# 8              244  1133
# 9              313  1374
# 10             133   624
# 11             173   469
# 12             266   875
# 13             344  1118
# 14             370  1344
# 15            1130  4452
# 16            2545  7418
# 17             650  1900
# 18             457  1438
# 19            1221  3639
# 20             240   492
# 21             737  1703
# 22             324  1337
# 23             205   759
# 24             352  1013
# 25             761  2972
# 26              97   318
# 27             291  1451
# 28             103   399
# 29             129   641
# 30             654  1954
# ...            ...   ...
# 59            1146  3132
# 60             327  1140
# 61             457  1176
# 62             605  1267
# ...

# %%
#Get Neighborhood names
neighborhood_names_df = pd.read_csv("neighborhoods.csv")
neighborhood_names_df
neighborhoods_df = pd.merge(neighborhood_names_df, neighborhood_crime_counts_df, on="Neighborhood")
neighborhoods_df.set_index("Neighborhood")
neighborhoods_df["crimes"]=neighborhoods_df["N"]+neighborhoods_df["V"]
neighborhoods_df = neighborhoods_df.sort_values(by=["crimes"])
neighborhoods_df
#neighborhoods_df.columns
# Out:
#     Neighborhood      Neighborhood Name     N     V  crimes
# 86            87       Botanical Garden     4    13      17
# 83            84           Penrose Park    16    41      57
# 84            85          O’Fallon Park    21    71      92
# 85            86       Cal-Bel Cemetery    23    70      93
# 82            83       Fairgrounds Park    38    91     129
# 80            81       Tower Grove Park    42    99     141
# 44            45         Wydown/Skinker    25   141     166
# 87            88          Wilmore Park     64   128     192
# 79            80        Carondelet Park    38   184     222
# 39            40              Kings Oak   124   152     276
# 25            26        Compton Heights    97   318     415
# 74            75              Riverview    96   320     416
# 48            49        Visitation Park    85   363     448
# 43            44              Hi-Pointe   101   362     463
# 27            28      Botanical Heights   103   399     502
# ...

# %%
#Bar Chart for "V" and "N" crimes per neighborhood
N = len(neighborhoods_df.index)
violentCrimes = neighborhoods_df["V"]
nonviolentCrimes = neighborhoods_df["N"]

ind = np.arange(N)    # the x locations for the groups

#width = 2       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(5*ind, violentCrimes, width = 4, color='r')
p2 = plt.bar(5*ind, nonviolentCrimes, width = 4, bottom=violentCrimes,color = 'b')

plt.rcParams["figure.figsize"]=[20,10]

plt.xlim([-5,450])

plt.ylabel("Crime Count")
plt.title("St. Louis Crimes By Neighborhoods")
names = neighborhoods_df["Neighborhood Name"]
plt.xticks(5*ind, names,rotation=90)

#plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ("Violent Crimes", "Non-Voilent Crimes"))

plt.show()

#neighborhoods_df.columns
